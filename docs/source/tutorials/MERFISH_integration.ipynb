# %%
import uniport as up
import scanpy as sc

# %%
adata_merfish = sc.read_h5ad('MERFISH/MERFISH.h5ad')
adata_rna = sc.read_h5ad('MERFISH/RNA.h5ad')
adata_cm = sc.read_h5ad('MERFISH/MERFISH_and_RNA.h5ad')

# %%
adatas = [adata_merfish, adata_rna]

# %%
adata = up.Run(adatas=adatas, adata_cm=adata_cm, lambda_kl=5.0)
# Out:
# Dataset 0: MERFISH
# AnnData object with n_obs × n_vars = 64373 × 155
#     obs: 'cell_type', 'domain_id', 'source'
#     var: 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'hvg', 'log1p'
# Dataset 1: RNA
# AnnData object with n_obs × n_vars = 30370 × 2000
#     obs: 'cell_type', 'domain_id', 'source'
#     var: 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'hvg', 'log1p'
# Reference dataset is dataset 1
#
#
# Data with common HVG
# AnnData object with n_obs × n_vars = 94743 × 153
#     obs: 'cell_type', 'domain_id', 'source'
#     var: 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'highly_variable_nbatches', 'highly_variable_intersection'
#     uns: 'hvg', 'log1p'
# 2022-05-08 11:08:10,803 - root - INFO - model
# VAE(
#   (encoder): Encoder(
#     (enc): ModuleList(
#       (0): NN(
#         (net): ModuleList(
#           (0): Block(
#             (fc): Linear(in_features=153, out_features=1024, bias=True)
#             (norm): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): ReLU()
#           )
#         )
#       )
#     )
#     (mu_enc): ModuleList(
#       (0): NN(
#         (net): ModuleList(
#           (0): Block(
#             (fc): Linear(in_features=1024, out_features=16, bias=True)
#           )
#         )
#       )
#     )
#     (var_enc): ModuleList(
#       (0): NN(
#         (net): ModuleList(
#           (0): Block(
#             (fc): Linear(in_features=1024, out_features=16, bias=True)
#           )
#         )
#       )
#     )
#   )
#   (decoder): Decoder(
#     (dec): ModuleList(
#       (0): NN(
#         (net): ModuleList(
#           (0): Block(
#             (fc): Linear(in_features=16, out_features=153, bias=True)
#             (norm): DSBatchNorm(
#               (bns): ModuleList(
#                 (0): BatchNorm1d(153, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (1): BatchNorm1d(153, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (act): Sigmoid()
#           )
#         )
#       )
#       (1): NN(
#         (net): ModuleList(
#           (0): Block(
#             (fc): Linear(in_features=16, out_features=155, bias=True)
#             (norm): BatchNorm1d(155, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): Sigmoid()
#           )
#         )
#       )
#       (2): NN(
#         (net): ModuleList(
#           (0): Block(
#             (fc): Linear(in_features=16, out_features=2000, bias=True)
#             (norm): BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): Sigmoid()
#           )
#         )
#       )
#     )
#   )
# )
# Epochs: 100%|█| 82/82 [12:13<00:00,  8.95s/it, recloss=795.66,klloss=29.17,otlo

# %%
sc.pp.neighbors(adata, use_rep='latent')
sc.tl.umap(adata, min_dist=0.1)
sc.pl.umap(adata, color=['source', 'cell_type'])
